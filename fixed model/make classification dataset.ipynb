# %%
#!/usr/bin/env python3
## import libraries
from keras.models import load_model
from keras.preprocessing import sequence
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
# set GPU memory
gpu_options = tf.GPUOptions(allow_growth=True)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %%
dataset = pd.read_csv("./raw datasets/back6.csv", header=None)
dataset = np.array(dataset)
dataset.shape
# Out:
# (980, 126)

# %%
dataset = dataset[:750, :90]
dataset.shape
# Out:
# (750, 90)

# %%
label = 7*np.ones(750)
label = label.reshape(750,1)
label.shape
# Out:
# (750, 1)

# %%
label
# Out:
# array([[7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
#        [7.],
# ...

# %%
dataset = np.hstack((label, dataset))
dataset
# Out:
# array([[  7.     ,  75.4456 , 294.846  , ...,  76.5471 , -10.6799 ,
#          13.1025 ],
#        [  7.     ,  75.6944 , 293.634  , ...,  79.7842 ,  -9.31186,
#          16.905  ],
#        [  7.     ,  76.3932 , 285.654  , ...,  85.6831 ,  -1.13116,
#          17.4617 ],
#        ...,
#        [  7.     ,  78.1175 , 280.556  , ...,  84.3266 , -32.2533 ,
#          16.2602 ],
#        [  7.     ,  74.3415 , 285.327  , ...,  84.3781 , -28.1629 ,
#          20.1196 ],
#        [  7.     ,  74.2836 , 276.308  , ...,  77.379  , -35.6578 ,
#          17.919  ]])

# %%
dataset.shape
# Out:
# (750, 91)

# %%
X = dataset[:, 1:]
X.shape
# Out:
# (750, 90)

# %%
Y = dataset[:,0]
Y.shape
# Out:
# (750,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3333, shuffle=True)

# %%
print("x_train shape = ", x_train.shape)
print("x_test shape = ", x_test.shape)
print("y_train shape = ", y_train.shape)
print("y_test shape = ", y_test.shape)
# Out:
# x_train shape =  (500, 90)
# x_test shape =  (250, 90)
# y_train shape =  (500,)
# y_test shape =  (250,)

# %%
df = pd.DataFrame(data=x_train, index=None, columns=None)
df.to_csv('./datasets/back6_train.csv')
df
# Out:
#            0        1        2         3        4        5         6   \
# 0     73.2251  329.392  41.9134   73.9906  315.902  41.4286   74.9744
# 1    100.1770  293.512  41.1814  100.2740  281.952  40.7131  100.3800
# 2     73.1029  295.772  41.8441   72.0331  282.353  41.4022   71.0186
# 3     92.3130  268.668  39.9669   90.8306  256.942  39.2994   89.5107
# 4     91.9187  295.225  40.9842   90.5666  280.920  40.7091   89.1452
# ..        ...      ...      ...       ...      ...      ...       ...
# 495   52.7635  279.466  40.5429   52.9414  267.910  39.7227   53.5499
# 496   74.6511  293.484  40.3767   74.3140  281.562  39.9932   73.9839
# 497   41.0941  315.250  42.3854   42.6569  302.029  42.2278   44.2185
# 498   71.8016  301.182  42.0691   71.2723  288.807  41.9135   70.7633
# 499   73.8159  284.275  39.3016   73.9886  270.344  38.6124   74.4003
#
#           7        8         9   ...        80        81        82       83  \
# ...

# %%
df = pd.DataFrame(data=x_test, index=None, columns=None)
df.to_csv('./datasets/back6_test.csv')
df
# Out:
#             0        1        2          3        4        5          6   \
# 0     42.16150  325.133  41.7372   43.54910  309.817  41.8335   44.75480
# 1     92.42490  295.031  41.7858   91.41810  283.294  41.5840   90.30480
# 2    147.07300  306.677  42.4858  144.59300  296.846  41.8888  141.50100
# 3    106.67400  268.403  38.9071  106.13200  254.613  38.3778  105.49000
# 4     88.68880  316.012  42.0865   88.26650  303.331  41.5941   88.28700
# ..         ...      ...      ...        ...      ...      ...        ...
# 245   72.57820  295.787  41.5878   71.26740  282.323  41.1615   70.26840
# 246   94.52070  306.254  40.3033   93.00120  295.613  39.0983   91.66870
# 247   78.58590  277.942  40.5440   78.66340  266.848  39.9012   78.69840
# 248   72.67080  330.900  41.9780   73.18160  317.170  42.0557   73.65970
# 249    3.06473  276.240  41.8667    6.10127  264.915  40.9897    9.60141
#
#           7        8         9   ...         80       81         82        83  \
# ...
